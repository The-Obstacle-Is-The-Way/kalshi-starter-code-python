# %% [markdown]
# # Edge Detection and Thesis Development
#
# Find trading opportunities and develop research theses based on market mispricing.

# %%
# Setup
from kalshi_research.analysis.scanner import MarketScanner
from kalshi_research.research.notebook_utils import load_markets, setup_notebook

setup_notebook()
# Out:
# Notebook configured for Kalshi research.

# %%
# Define your estimates for specific markets
my_estimates = {
    # "TICKER-HERE": 0.65,  # You think 65%, market may differ
    # Add your own market estimates here
}

print(f"Analyzing {len(my_estimates)} markets with custom estimates")
# Out:
# Analyzing 0 markets with custom estimates

# %%
# Detect edges based on your estimates
# detector = EdgeDetector()
# for ticker, my_prob in my_estimates.items():
#     # Fetch current market (implement your data fetching)
#     # market = await get_market(ticker)
#     # edge = detector.detect_thesis_edge(
#     #     ticker=ticker,
#     #     market_prob=market.yes_price / 100.0,
#     #     your_prob=my_prob,
#     # )
#     # if edge:
#     #     display_edge(edge)

# %%
# Scan for opportunities (close races, extreme confidence, etc.)
markets_df = await load_markets(status="open", limit=500)
scanner = MarketScanner()

# Find close races (markets near 50%)
# close_races = scanner.scan_close_races(markets_df, top_n=10)
# print(f"Found {len(close_races)} close races")

# %%
# Create a thesis for a promising opportunity
# thesis = Thesis(
#     id="my-thesis-001",
#     title="Your thesis title here",
#     market_tickers=["TICKER-HERE"],
#     your_probability=0.65,
#     market_probability=0.50,
#     confidence=0.75,
#     bull_case="Why YES could happen...",
#     bear_case="Why NO could happen...",
#     key_assumptions=["Assumption 1", "Assumption 2"],
#     invalidation_criteria=["What would prove me wrong"],
# )
#
# # Save thesis
# tracker = ThesisTracker()
# tracker.add(thesis)
# print(thesis)
