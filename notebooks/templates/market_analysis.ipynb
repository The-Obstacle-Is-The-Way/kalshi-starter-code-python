# %% [markdown]
# # Market Analysis Template
#
# Use this template to analyze any specific market in depth.
#
# **Market:** [TICKER]
# **Question:** [Market question]
# **Analysis Date:** [Date]

# %%
# Setup
from kalshi_research.api import KalshiPublicClient
from kalshi_research.research.notebook_utils import display_market, setup_notebook

setup_notebook()

# Specify the market ticker you want to analyze
TICKER = "YOUR-TICKER-HERE"

# %%
# Fetch market data
async with KalshiPublicClient() as client:
    market = await client.get_market(TICKER)

display_market(market)

# %% [markdown]
# ## Current State
#
# - **Current Probability:** [X%]
# - **Volume:** [X contracts]
# - **Spread:** [X cents]
# - **Days until close:** [X days]

# %% [markdown]
# ## Analysis
#
# ### Bull Case (Why YES)
# - Point 1
# - Point 2
# - Point 3
#
# ### Bear Case (Why NO)
# - Point 1
# - Point 2
# - Point 3
#
# ### Key Factors
# - Factor 1: Impact and likelihood
# - Factor 2: Impact and likelihood
# - Factor 3: Impact and likelihood

# %% [markdown]
# ## My Estimate
#
# Based on the analysis above:
#
# - **My Probability:** [X%]
# - **Market Probability:** [Y%]
# - **Edge:** [X - Y]%
# - **Confidence:** [Low/Medium/High]

# %% [markdown]
# ## Decision
#
# - [ ] Take position
# - [ ] Monitor
# - [ ] Pass
#
# **Reasoning:** [Your reasoning here]

# %%
# Create thesis if taking position
# from kalshi_research.research.thesis import Thesis, ThesisTracker
#
# thesis = Thesis(
#     id=f"thesis-{TICKER}",
#     title="[Your thesis title]",
#     market_tickers=[TICKER],
#     your_probability=0.XX,  # Your estimate
#     market_probability=market.yes_price / 100.0,
#     confidence=0.XX,  # Your confidence level
#     bull_case="...",
#     bear_case="...",
#     key_assumptions=["..."],
#     invalidation_criteria=["..."],
# )
#
# tracker = ThesisTracker()
# tracker.add(thesis)
